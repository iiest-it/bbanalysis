# %%
import matplotlib

# %%
matplotlib.get_backend()
# Out:
# 'nbAgg'

# %%
# %matplotlib notebook

# %%
import numpy as np
import pandas as pd
import json
from scipy.spatial import ConvexHull, Voronoi, voronoi_plot_2d
from Game import Game
import subprocess
import os

# %%
pd.set_option('display.max_columns', 50)

# %%
with open('0021500495.json') as f:
    gm=json.load(f)

# %%
df=pd.DataFrame(gm['events'])

# %%
with open('0021500495-pbp.json') as f:
    pbp=json.load(f)

# %%
pbp_df=pd.DataFrame(pbp['resultSets'][0]['rowSet'], columns=pbp['resultSets'][0]['headers'])

# %%
makes=pbp_df[(pbp_df['EVENTMSGTYPE']==1)]
free_throws=pbp_df[(pbp_df['EVENTMSGTYPE']==3)]

# %%
makes
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 2    0021500495         2             1                  44       1
# 9    0021500495         9             1                  63       1
# 16   0021500495        16             1                   5       1
# 21   0021500495        22             1                  66       1
# 22   0021500495        23             1                   1       1
# 24   0021500495        25             1                   1       1
# 29   0021500495        30             1                  87       1
# 40   0021500495        47             1                  75       1
# 43   0021500495        50             1                   1       1
# 44   0021500495        51             1                   5       1
# 49   0021500495        56             1                  72       1
# 52   0021500495        60             1                  79       1
# 53   0021500495        61             1                   1       1
# ...

# %%
game=Game('0021500495.json', makes['EVENTNUM'].iloc[0])

# %%
# %matplotlib qt
game.start()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
moments={}
for e in gm['events']:
    for m in e['moments']:
        moments[m[1]]=m

# %%
len(moments)
# Out:
# 80969
